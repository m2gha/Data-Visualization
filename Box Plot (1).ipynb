# %%
#Box plot
import matplotlib.pyplot as plt
import pandas as pd

wine_quality=pd.read_csv('winequality.csv',delimiter=';')
data=[wine_quality['alcohol'],wine_quality['fixed acidity'],wine_quality['quality']]
plt.boxplot(data)
plt.show()

# %%
#Box plot
import pandas as pd

import matplotlib.pyplot as plt



all_boards = pd.read_csv("LaserCutBoardthickness.csv")

boards = all_boards.iloc[0:100, 1:7]



# Look at the start and end of the data

# Examine and summarize your data before

# doing anything else

boards.head()

boards.tail()

boards.describe()

ax = boards.plot.box(fontsize=16)

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

wine_quality=pd.read_csv('winequality.csv',delimiter=';')
data=[wine_quality['alcohol'],wine_quality['fixed acidity'],wine_quality['quality']]

plt.boxplot(data,vert=False,flierprops=dict(markerfacecolor='r',marker='D'))
plt.show();
